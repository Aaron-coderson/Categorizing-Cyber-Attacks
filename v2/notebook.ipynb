# %% [markdown]
# # **Cyber-Attack Analysis: Methodology and Execution**
#
# ## **1. Introduction**
# This notebook follows the methodology outlined in the research flowchart to analyze cyber-attacks using data from the CISSM website. It includes exploratory data analysis, distribution analysis, advanced statistical analysis, and predictive modeling.
#
# ---
#
# ## **2. Data Import**
# - Source: CISSM website (includes over 14,000 recorded cyber-attack events from 2014 to 2024)
# - Data Cleaning and Preprocessing
#
# ---
#
# ## **3. Exploratory Data Analysis (EDA)**
# ### **3.1 Distribution Analysis**
# - Cyber-attack frequency across all industries
# - Cyber-attack type distribution across all industries
# - Cyber-attack actor-type distribution across all industries
#
# ---
#
# ## **4. Cyber-Attack Actor and Motive Analysis**
# ### **4.1 Motive Analysis**
# - Distribution of cyber-attack motives across industries
#
# ### **4.2 Geographic Distribution**
# - Distribution of affected countries
# - Distribution of actor countries
#
# ### **4.3 Industry-Specific Analysis**
# - Filtering public administration and healthcare-related attacks by type & motive
# - Addressing discrepancies vs. hypothesis
#
# ---
#
# ## **5. Advanced Statistical Analysis**
# - **Cyber-attacks vs. GDP**
# - **Cyber-attacks vs. Gini Coefficient**
#
# ---
#
# ## **6. Time-Series Analysis**
# ### **6.1 Visualization**
# - Historical frequency of cyber-attacks
#
# ### **6.2 Predictive Modeling**
# - ARIMA model for cyber-attack frequency prediction
#
# ---
#
# ## **7. Discussion and Conclusion**
# - Interpretation of results
# - Key insights
# - Future research directions

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
import plotly
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# ## **Data Import**

# %%
df = pd.read_csv("data/cissm_data.csv", encoding="latin-1")

# %% [markdown]
# ## **EDA Distribution**
# first code below sets up df's

# %%
## event_counts stores cyber event types over all indsustries
event_counts = df.groupby("event_type").size().reset_index(name="counts")
event_counts
# Out:
#      event_type  counts
# 0    Disruptive    4360
# 1    Exploitive    7000
# 2         Mixed    2500
# 3  Undetermined     181

# %%
## motive_counts stores motive over all industries
motive_counts = df.groupby("motive").size().reset_index(name="counts")
motive_counts
# Out:
#                         motive  counts
# 0                    Financial    8034
# 1         Industrial-Espionage      94
# 2              Personal Attack      93
# 3          Political-Espionage     679
# 4                      Protest    1680
# 5            Protest,Financial       1
# 6  Protest;Political-Espionage       1
# 7                     Sabotage     340
# 8                 Undetermined    3119

# %%
## actor_counts stores actor types over all industries
actor_counts = df.groupby("actor_type").size().reset_index(name="counts")
actor_counts
# Out:
#      actor_type  counts
# 0      Criminal   10676
# 1    Hacktivist    1909
# 2     Hacktvist      17
# 3      Hobbyist     191
# 4  Nation-State     803
# 5     Terrorist      30
# 6  Undetermined     415

# %%
## monthly counts stores month, event_type, and industry
monthly_counts = (
    df.groupby(["month", "event_type", "industry"]).size().reset_index(name="count")
)

# %%
## dfEventType stores occurrences of each event type within each industry
dfEventType = df.groupby("industry")["event_type"].value_counts().unstack(fill_value=0)

# Rename columns for clarity
dfEventType = dfEventType.rename(
    columns={
        "Undetermined": "undetermined_eventType_count",
        "Mixed": "mixed_eventType_count",
        "Exploitive": "exploititive_eventType_count",
        "Disruptive": "disruptive_eventType_count",
    }
)

# Calculate total counts for each industry
dfEventType["industry_counts"] = dfEventType.sum(axis=1)

# Reset index to make 'industry' a regular column
dfEventType = dfEventType.reset_index()

# Sort dfEventType by industry_counts in ascending order
dfEventType = dfEventType.sort_values(by="industry_counts", ascending=True)
dfEventType.head()
# Out:
# event_type                                    industry  \
# 12                                              Medusa
# 2           Agriculture, Forestry, Fishing and Hunting
# 10             Management of Companies and Enterprises
# 8                      Health Care and Social Services
# 4                                         Construction
#
# event_type  disruptive_eventType_count  exploititive_eventType_count  \
# 12                                   0                             0
# 2                                    6                             3
# 10                                   5                             8
# 8                                    4                            11
# 4                                    9                            10
#
# event_type  mixed_eventType_count  undetermined_eventType_count  \
# 12                              1                             0
# 2                               9                             0
# 10                              7                             0
# 8                              11                             1
# 4                              27                             1
#
# event_type  industry_counts
# 12                        1
# 2                        18
# 10                       20
# 8                        27
# 4                        47

# %%
## dfActorType stores occurences of each actor_type within each industry
dfActorType = df.groupby("industry")["actor_type"].value_counts().unstack(fill_value=0)
dfActorType["industry_counts"] = dfActorType.sum(axis=1)
dfActorType = dfActorType.reset_index()
dfActorType = dfActorType.sort_values(by="industry_counts", ascending=True)
dfActorType.head()
# Out:
# actor_type                                    industry  Criminal  Hacktivist  \
# 12                                              Medusa         1           0
# 2           Agriculture, Forestry, Fishing and Hunting        13           4
# 10             Management of Companies and Enterprises        16           2
# 8                      Health Care and Social Services        27           0
# 4                                         Construction        39           7
#
# actor_type  Hacktvist  Hobbyist  Nation-State  Terrorist  Undetermined  \
# 12                  0         0             0          0             0
# 2                   0         0             1          0             0
# 10                  0         0             2          0             0
# 8                   0         0             0          0             0
# 4                   0         1             0          0             0
#
# actor_type  industry_counts
# 12                        1
# 2                        18
# 10                       20
# 8                        27
# 4                        47

# %%
## dfMotive stores occurrences of each motive type within each industry
dfMotive = df.groupby("industry")["motive"].value_counts().unstack(fill_value=0)
dfMotive["industry_counts"] = dfMotive.sum(axis=1)
dfMotive = dfMotive.reset_index()
dfMotive = dfMotive.sort_values(by="industry_counts", ascending=True)
dfMotive.rename(
    columns={"industry": "Sector Title", "Undetermined": "Undetermined Motive"},
    inplace=True,
)
dfMotive.head()
# Out:
# motive                                Sector Title  Financial  \
# 12                                          Medusa          1
# 2       Agriculture, Forestry, Fishing and Hunting         10
# 10         Management of Companies and Enterprises         13
# 8                  Health Care and Social Services         27
# 4                                     Construction         34
#
# motive  Industrial-Espionage  Personal Attack  Political-Espionage  Protest  \
# 12                         0                0                    0        0
# 2                          0                0                    0        4
# 10                         0                0                    1        2
# 8                          0                0                    0        0
# 4                          0                0                    0        8
#
# motive  Protest,Financial  Protest;Political-Espionage  Sabotage  \
# 12                      0                            0         0
# 2                       0                            0         1
# 10                      0                            0         1
# 8                       0                            0         0
# 4                       0                            0         0
#
# motive  Undetermined Motive  industry_counts
# 12                        0                1
# 2                         3               18
# 10                        3               20
# 8                         0               27
# 4                         5               47

# %%
## combine dfEventType, dfActorType, and dfMotive type into final merged df

dfActorType = dfActorType.sort_values(by="industry_counts", ascending=True)
dfEventType = dfEventType.sort_values(by="industry_counts", ascending=True)
dfMotive = dfMotive.sort_values(by="industry_counts", ascending=True)
dfActorType.rename(columns={"industry": "Sector Title"}, inplace=True)
dfEventType.rename(columns={"industry": "Sector Title"}, inplace=True)
dfMotive.rename(columns={"industry": "Sector Title"}, inplace=True)

merged_df = pd.merge(dfEventType, dfActorType, on="Sector Title", how="outer")
final_merged_df = pd.merge(merged_df, dfMotive, on="Sector Title", how="outer")
final_merged_df = final_merged_df.sort_values(by="industry_counts_y", ascending=True)
final_merged_df.head()
# Out:
#                                  Sector Title  disruptive_eventType_count  \
# 0                                      Medusa                           0
# 1  Agriculture, Forestry, Fishing and Hunting                           6
# 2     Management of Companies and Enterprises                           5
# 3             Health Care and Social Services                           4
# 4                                Construction                           9
#
#    exploititive_eventType_count  mixed_eventType_count  \
# 0                             0                      1
# 1                             3                      9
# 2                             8                      7
# 3                            11                     11
# 4                            10                     27
#
#    undetermined_eventType_count  industry_counts_x  Criminal  Hacktivist  \
# 0                             0                  1         1           0
# 1                             0                 18        13           4
# 2                             0                 20        16           2
# 3                             1                 27        27           0
# 4                             1                 47        39           7
#
#    Hacktvist  Hobbyist  ...  Financial  Industrial-Espionage  Personal Attack  \
# 0          0         0  ...          1                     0                0
# 1          0         0  ...         10                     0                0
# 2          0         0  ...         13                     0                0
# 3          0         0  ...         27                     0                0
# 4          0         1  ...         34                     0                0
#
#    Political-Espionage  Protest  Protest,Financial  \
# 0                    0        0                  0
# 1                    0        4                  0
# 2                    1        2                  0
# 3                    0        0                  0
# 4                    0        8                  0
#
#    Protest;Political-Espionage  Sabotage  Undetermined Motive  industry_counts
# 0                            0         0                    0                1
# 1                            0         1                    3               18
# 2                            0         1                    3               20
# 3                            0         0                    0               27
# 4                            0         0                    5               47
#
# [5 rows x 24 columns]

# %%
## create lists of values for certain columns for use throughout
listEvent = [
    "disruptive_count",
    "exploitive_count",
    "mixed_count",
    "undetermined_count",
]

listActor = [
    "Criminal",
    "Hacktivist",
    "Hobbyist",
    "Nation-State",
    "Terrorist",
    "Undetermined",
]

listMotive = [
    "Financial",
    "Industrial-Espionage",
    "Personal Attack",
    "Political-Espionage",
    "Protest",
    "Protest,Financial",
    "Protest;Political-Espionage",
    "Sabotage",
    "Undetermined Motive",
]

industry_types = [
    "Agriculture, Forestry, Fishing and HuntingMining",
    "Utilities",
    "Construction",
    "Manufacturing",
    "Wholesale Trade",
    "Retail Trade",
    "Transportation and Warehousing",
    "Information",
    "Finance and Insurance",
    "Real Estate Rental and Leasing",
    "Professional, Scientific, and Technical Services",
    "Management of Companies and Enterprises",
    "Administrative and Support and Waste Management and Remediation Services",
    "Educational Services",
    "Health Care and Social Assistance",
    "Arts, Entertainment, and Recreation",
    "Accommodation and Food Services",
    "Other Services (except Public Administration)",
    "Public Administration",
]

# %%
## create industryDF which stores event_date, industry, and counts
## create timeDF which stores event_date and counts

df["event_date"] = pd.to_datetime(df["event_date"], format="mixed")

event_types = ["Undetermined", "Disruptive", "Exploitive", "Mixed"]
filtered_df = df[df["event_type"].isin(event_types)]

timeDf = (
    filtered_df.groupby([pd.Grouper(key="event_date", freq="M")])
    .size()
    .reset_index(name="counts")
)

# Convert event_date to datetime
df["event_date"] = pd.to_datetime(df["event_date"])

# Filter rows based on event_type values
event_types = ["Undetermined", "Disruptive", "Exploitive", "Mixed"]
filtered_df = df[df["event_type"].isin(event_types)]

# Group by year, month, and event_type, then count occurrences
grouped_df = (
    filtered_df.groupby([pd.Grouper(key="event_date", freq="M"), "event_type"])
    .size()
    .reset_index(name="counts")
)


filtered_df = df[df["industry"].isin(industry_types)]

# Group by year, month, and event_type, then count occurrences
industryDf = (
    filtered_df.groupby([pd.Grouper(key="event_date", freq="M"), "industry"])
    .size()
    .reset_index(name="counts")
)

# %%
# df_health contains only the data of attacks on the Health Care and Social Assistance industr
df_health = df[df["industry"] == "Health Care and Social Assistance"]

# %%
# df_publicAdmin contains only data of attacks on the Public Adminsitration Industry
df_publicAdmin = df[df["industry"] == "Public Administration"]

# %% [markdown]
# **Graph**

# %%
## add all

# %% [markdown]
# **Cyber-Attack Actor & Motive Analysis**

# %% [markdown]
# **Gini & GDP Bining**

# %% [markdown]
# ## **Time Series**

# %% [markdown]
# ## **Split 2014-2019/2020-2024**

# %%
df
# Out:
#                    slug event_date  year  month                   actor  \
# 0      1f72c2eb8ab303e4 2014-01-01  2014      1            Undetermined
# 1      ecac8b3e60a2f72f 2014-01-01  2014      1            Undetermined
# 2      3bbe0695e2d019f3 2014-01-01  2014      1  Syrian Electronic Army
# 3      6100014f6ca84b3d 2014-01-02  2014      1            Undetermined
# 4      3a94b8cf6dde1f66 2014-01-03  2014      1           DERP Trolling
# ...                 ...        ...   ...    ...                     ...
# 14036  9099BBAE1A95E0AD 2024-05-10  2024      5             LockBit 3.0
# 14037  A81573A2AD4D7527 2024-05-01  2024      5             Black Basta
# 14038  25D303249D037FE0 2023-05-01  2023      5            Undetermined
# 14039  2E80B2C74A7F38A7 2024-05-01  2024      5            Undetermined
# 14040  7462B1CFC4522C95 2023-10-01  2024     10             IntelBroker
#
#          actor_type                   organization  industry_code  \
# 0          Criminal               Barry University             61
# 1          Criminal              Record Assist LLC             54
# 2        Hacktivist           Skype's Social Media             54
# 3          Criminal                       Snapchat             51
# 4      Undetermined                     Battle.net             51
# ...             ...                            ...            ...
# 14036      Criminal            University of Siena             61
# 14037      Criminal                          Atlas             21
# 14038  Undetermined      Western Sydney University             61
# 14039      Criminal  At least three Wyndham hotels             72
# 14040      Criminal                        Zscaler             54
#
#                                                industry        motive  \
# 0                                  Educational Services  Undetermined
# 1      Professional, Scientific, and Technical Services  Undetermined
# 2      Professional, Scientific, and Technical Services       Protest
# 3                                           Information  Undetermined
# 4                                           Information  Undetermined
# ...                                                 ...           ...
# 14036                              Educational Services     Financial
# 14037     Mining, Quarrying, and Oil and Gas Extraction     Financial
# 14038                              Educational Services  Undetermined
# 14039                   Accommodation and Food Services     Financial
# 14040  Professional, Scientific, and Technical Services     Financial
#
#          event_type                                    event_subtype  \
# 0        Exploitive                        Exploitation of End Hosts
# 1        Exploitive               Exploitation of Application Server
# 2        Disruptive                             Message Manipulation
# 3        Exploitive               Exploitation of Application Server
# 4        Disruptive                       External Denial of Service
# ...             ...                                              ...
# 14036         Mixed  Data Attack; Exploitation of Application Server
# 14037         Mixed  Data Attack; Exploitation of Application Server
# 14038  Undetermined                                     Undetermined
# 14039    Exploitive               Exploitation of Application Server
# 14040    Exploitive               Exploitation of Application Server
#
#                                              description  \
# 0      Barry University notifies patients of its Foot...
# 1      Record Assist LLC notifies of an unauthorized ...
# 2      The Syrian Electronic Army hacks Skype's Twitt...
# 3      Greyhat hackers publish the partial phone numb...
# 4      The servers for Steam, Origin, Battle.net, and...
# ...                                                  ...
# 14036  The University of Siena is hit with a LockBit ...
# 14037  The Back Basta extortion group claims to have ...
# 14038  Western Sydney University (WSU) notifies stude...
# 14039  pcTattletale, a consumer-grade spyware app is ...
# 14040  Zscaler says that they discovered an exposed "...
#
#                                               source_url  \
# 0      https://www.beckershospitalreview.com/healthca...
# 1      https://privacyrights.org/data-breaches/record...
# 2      http://thenextweb.com/microsoft/2014/01/01/sky...
# 3      http://arstechnica.com/security/2014/01/greyha...
# 4      http://arstechnica.com/gaming/2014/01/multiple...
# ...                                                  ...
# 14036  https://thecyberexpress.com/lockbit-university...
# 14037  https://securityaffairs.com/163489/cyber-crime...
# 14038  https://www.bleepingcomputer.com/news/security...
# 14039  https://techcrunch.com/2024/05/22/spyware-foun...
# 14040  https://www.bleepingcomputer.com/news/security...
#
#                         country         actor_country  \
# 0      United States of America          Undetermined
# 1      United States of America          Undetermined
# 2      United States of America  Syrian Arab Republic
# 3      United States of America          Undetermined
# 4      United States of America          Undetermined
# ...                         ...                   ...
# 14036                     Italy          Undetermined
# 14037  United States of America    Russian Federation
# 14038                 Australia          Undetermined
# 14039  United States of America          Undetermined
# 14040  United States of America          Undetermined
#
#                                               change_log
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14036                                                NaN
# 14037                                                NaN
# 14038  *Cyber event detected and/or reported in 2024 ...
# 14039                                                NaN
# 14040                                                NaN
#
# [14041 rows x 17 columns]

# %%
dfTimeBased = df
dfTimeBased["event_date"] = pd.to_datetime(dfTimeBased["event_date"])
dfTimeBased = dfTimeBased.set_index(dfTimeBased["event_date"])
dfTimeBased = dfTimeBased.sort_index()

# %%
early = dfTimeBased["2014-01-01":"2019-12-30"]
late = dfTimeBased["2019-12-30":"2024-05-01"]

# %%
df = early

# eda create df's same as earlier

# df = pd.read_csv("data/cissm_data.csv", encoding="latin-1")

## event_counts stores cyber event types over all indsustries
event_counts = df.groupby("event_type").size().reset_index(name="counts")
event_counts

## motive_counts stores motive over all industries
motive_counts = df.groupby("motive").size().reset_index(name="counts")
motive_counts

## actor_counts stores actor types over all industries
actor_counts = df.groupby("actor_type").size().reset_index(name="counts")
actor_counts

## monthly counts stores month, event_type, and industry
monthly_counts = (
    df.groupby(["month", "event_type", "industry"]).size().reset_index(name="count")
)

## dfEventType stores occurrences of each event type within each industry
dfEventType = df.groupby("industry")["event_type"].value_counts().unstack(fill_value=0)

# Rename columns for clarity
dfEventType = dfEventType.rename(
    columns={
        "Undetermined": "undetermined_eventType_count",
        "Mixed": "mixed_eventType_count",
        "Exploitive": "exploititive_eventType_count",
        "Disruptive": "disruptive_eventType_count",
    }
)

# Calculate total counts for each industry
dfEventType["industry_counts"] = dfEventType.sum(axis=1)

# Reset index to make 'industry' a regular column
dfEventType = dfEventType.reset_index()

# Sort dfEventType by industry_counts in ascending order
dfEventType = dfEventType.sort_values(by="industry_counts", ascending=True)
dfEventType.head()

## dfActorType stores occurences of each actor_type within each industry
dfActorType = df.groupby("industry")["actor_type"].value_counts().unstack(fill_value=0)
dfActorType["industry_counts"] = dfActorType.sum(axis=1)
dfActorType = dfActorType.reset_index()
dfActorType = dfActorType.sort_values(by="industry_counts", ascending=True)
dfActorType.head()

## dfMotive stores occurrences of each motive type within each industry
dfMotive = df.groupby("industry")["motive"].value_counts().unstack(fill_value=0)
dfMotive["industry_counts"] = dfMotive.sum(axis=1)
dfMotive = dfMotive.reset_index()
dfMotive = dfMotive.sort_values(by="industry_counts", ascending=True)
dfMotive.rename(
    columns={"industry": "Sector Title", "Undetermined": "Undetermined Motive"},
    inplace=True,
)
dfMotive.head()

## combine dfEventType, dfActorType, and dfMotive type into final merged df

dfActorType = dfActorType.sort_values(by="industry_counts", ascending=True)
dfEventType = dfEventType.sort_values(by="industry_counts", ascending=True)
dfMotive = dfMotive.sort_values(by="industry_counts", ascending=True)
dfActorType.rename(columns={"industry": "Sector Title"}, inplace=True)
dfEventType.rename(columns={"industry": "Sector Title"}, inplace=True)
dfMotive.rename(columns={"industry": "Sector Title"}, inplace=True)

merged_df = pd.merge(dfEventType, dfActorType, on="Sector Title", how="outer")
final_merged_df = pd.merge(merged_df, dfMotive, on="Sector Title", how="outer")
final_merged_df = final_merged_df.sort_values(by="industry_counts_y", ascending=True)
final_merged_df.head()

## create lists of values for certain columns for use throughout
listEvent = [
    "disruptive_count",
    "exploitive_count",
    "mixed_count",
    "undetermined_count",
]

listActor = [
    "Criminal",
    "Hacktivist",
    "Hobbyist",
    "Nation-State",
    "Terrorist",
    "Undetermined",
]

listMotive = [
    "Financial",
    "Industrial-Espionage",
    "Personal Attack",
    "Political-Espionage",
    "Protest",
    "Protest,Financial",
    "Protest;Political-Espionage",
    "Sabotage",
    "Undetermined Motive",
]

industry_types = [
    "Agriculture, Forestry, Fishing and HuntingMining",
    "Utilities",
    "Construction",
    "Manufacturing",
    "Wholesale Trade",
    "Retail Trade",
    "Transportation and Warehousing",
    "Information",
    "Finance and Insurance",
    "Real Estate Rental and Leasing",
    "Professional, Scientific, and Technical Services",
    "Management of Companies and Enterprises",
    "Administrative and Support and Waste Management and Remediation Services",
    "Educational Services",
    "Health Care and Social Assistance",
    "Arts, Entertainment, and Recreation",
    "Accommodation and Food Services",
    "Other Services (except Public Administration)",
    "Public Administration",
]

## create industryDF which stores event_date, industry, and counts
## create timeDF which stores event_date and counts

df["event_date"] = pd.to_datetime(df["event_date"], format="mixed")

event_types = ["Undetermined", "Disruptive", "Exploitive", "Mixed"]
filtered_df = df[df["event_type"].isin(event_types)]

timeDf = (
    filtered_df.groupby([pd.Grouper(key="event_date", freq="M")])
    .size()
    .reset_index(name="counts")
)

# Convert event_date to datetime
df["event_date"] = pd.to_datetime(df["event_date"])

# Filter rows based on event_type values
event_types = ["Undetermined", "Disruptive", "Exploitive", "Mixed"]
filtered_df = df[df["event_type"].isin(event_types)]

# Group by year, month, and event_type, then count occurrences
grouped_df = (
    filtered_df.groupby([pd.Grouper(key="event_date", freq="M"), "event_type"])
    .size()
    .reset_index(name="counts")
)


filtered_df = df[df["industry"].isin(industry_types)]

# Group by year, month, and event_type, then count occurrences
industryDf = (
    filtered_df.groupby([pd.Grouper(key="event_date", freq="M"), "industry"])
    .size()
    .reset_index(name="counts")
)
# Out:
# /var/folders/w9/488y8jbj0plfk1q3x8hrsdgw0000gn/T/ipykernel_81831/286688771.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["event_date"] = pd.to_datetime(df["event_date"], format="mixed")
# /var/folders/w9/488y8jbj0plfk1q3x8hrsdgw0000gn/T/ipykernel_81831/286688771.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["event_date"] = pd.to_datetime(df["event_date"])

# %%
industry_counts = df["industry"].value_counts().sort_values(ascending=True)
plt.figure(figsize=(10, 8))
industry_counts.plot(kind="bar")
plt.xlabel("Number of Attacks")
plt.ylabel("Industry")
_ = plt.title("Figure 1: Distribution of Cyber Attacks Across Industries")
# this code graphs the number of cyber attacks per industry using Matplotlib

# %%
df
# Out:
#                         slug event_date  year  month  \
# event_date
# 2014-01-01  1f72c2eb8ab303e4 2014-01-01  2014      1
# 2014-01-01  ecac8b3e60a2f72f 2014-01-01  2014      1
# 2014-01-01  3bbe0695e2d019f3 2014-01-01  2014      1
# 2014-01-02  6100014f6ca84b3d 2014-01-02  2014      1
# 2014-01-03  1389e2776dea37ba 2014-01-03  2014      1
# ...                      ...        ...   ...    ...
# 2019-12-29  9af721068dee16dc 2019-12-29  2019     12
# 2019-12-30  9ffee1ae29b11af5 2019-12-30  2019     12
# 2019-12-30  50a9874e87f92e38 2019-12-30  2019     12
# 2019-12-30  613695f407e4f729 2019-12-30  2019     12
# 2019-12-30  b7eb92c653ed69e0 2019-12-30  2019     12
#
#                                                         actor    actor_type  \
# event_date
# 2014-01-01                                       Undetermined      Criminal
# 2014-01-01                                       Undetermined      Criminal
# 2014-01-01                             Syrian Electronic Army    Hacktivist
# 2014-01-02                                       Undetermined      Criminal
# 2014-01-03                                      DERP Trolling  Undetermined
# ...                                                       ...           ...
# 2019-12-29  Ministry of Intelligence and Security (MOIS) (...  Nation-State
# 2019-12-30                                       Undetermined      Criminal
# 2019-12-30                                       Undetermined      Criminal
# 2019-12-30                                       Undetermined      Criminal
# 2019-12-30                                      WIZARD SPIDER      Criminal
#
#                              organization  industry_code  \
# event_date
# 2014-01-01               Barry University             61
# 2014-01-01              Record Assist LLC             54
# 2014-01-01           Skype's Social Media             54
# 2014-01-02                       Snapchat             51
# 2014-01-03                 World of Tanks             51
# ...                                   ...            ...
# 2019-12-29                          Bapco             21
# 2019-12-30                 Active Network             54
# 2019-12-30                       Poloniex             52
# 2019-12-30                   Town of Erie             92
# 2019-12-30  Undisclosed maritime facility             92
#
#                                                     industry        motive  \
# event_date
# 2014-01-01                              Educational Services  Undetermined
# 2014-01-01  Professional, Scientific, and Technical Services  Undetermined
# 2014-01-01  Professional, Scientific, and Technical Services       Protest
# 2014-01-02                                       Information  Undetermined
# 2014-01-03                                       Information  Undetermined
# ...                                                      ...           ...
# 2019-12-29     Mining, Quarrying, and Oil and Gas Extraction      Sabotage
# 2019-12-30  Professional, Scientific, and Technical Services     Financial
# 2019-12-30                             Finance and Insurance  Undetermined
# 2019-12-30                             Public Administration     Financial
# 2019-12-30                             Public Administration     Financial
#
#             event_type                                      event_subtype  \
# event_date
# 2014-01-01  Exploitive                          Exploitation of End Hosts
# 2014-01-01  Exploitive                 Exploitation of Application Server
# 2014-01-01  Disruptive                               Message Manipulation
# 2014-01-02  Exploitive                 Exploitation of Application Server
# 2014-01-03  Disruptive                         External Denial of Service
# ...                ...                                                ...
# 2019-12-29  Disruptive                                        Data Attack
# 2019-12-30  Exploitive                 Exploitation of Application Server
# 2019-12-30  Exploitive                 Exploitation of Application Server
# 2019-12-30  Disruptive                               Message Manipulation
# 2019-12-30  Disruptive  External Denial of Service,Data Attack,Interna...
#
#                                                   description  \
# event_date
# 2014-01-01  Barry University notifies patients of its Foot...
# 2014-01-01  Record Assist LLC notifies of an unauthorized ...
# 2014-01-01  The Syrian Electronic Army hacks Skype's Twitt...
# 2014-01-02  Greyhat hackers publish the partial phone numb...
# 2014-01-03  The servers for Steam, Origin, Battle.net, and...
# ...                                                       ...
# 2019-12-29  Multiple sources reveal that Iranian state-spo...
# 2019-12-30  School software vendor Active Network notifies...
# 2019-12-30  The Poloniex Exchange forces a password reset ...
# 2019-12-30  Colorado Town of Erie loses more than $1 milli...
# 2019-12-30  The U.S. Coast Guard issues a security alert a...
#
#                                                    source_url  \
# event_date
# 2014-01-01  https://www.beckershospitalreview.com/healthca...
# 2014-01-01  https://privacyrights.org/data-breaches/record...
# 2014-01-01  http://thenextweb.com/microsoft/2014/01/01/sky...
# 2014-01-02  http://arstechnica.com/security/2014/01/greyha...
# 2014-01-03  http://arstechnica.com/gaming/2014/01/multiple...
# ...                                                       ...
# 2019-12-29  https://www.zdnet.com/article/new-iranian-data...
# 2019-12-30  https://www.scmagazine.com/home/security-news/...
# 2019-12-30  https://bitcoinist.com/poloniex-exchange-secur...
# 2019-12-30  https://www.bleepingcomputer.com/news/security...
# 2019-12-30  https://www.govinfosecurity.com/us-coast-guard...
#
#                              country               actor_country change_log
# event_date
# 2014-01-01  United States of America                Undetermined        NaN
# 2014-01-01  United States of America                Undetermined        NaN
# 2014-01-01  United States of America        Syrian Arab Republic        NaN
# 2014-01-02  United States of America                Undetermined        NaN
# 2014-01-03  United States of America                Undetermined        NaN
# ...                              ...                         ...        ...
# 2019-12-29                   Bahrain  Iran (Islamic Republic of)        NaN
# 2019-12-30  United States of America                Undetermined        NaN
# 2019-12-30                    Poland                Undetermined        NaN
# 2019-12-30  United States of America                Undetermined        NaN
# 2019-12-30  United States of America          Russian Federation        NaN
#
# [5291 rows x 17 columns]
